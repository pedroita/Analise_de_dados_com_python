# %%
import pandas as pd
import numpy  as np

# %%
df = pd.read_csv('./disney_plus_titles.csv')

# %%
df_dados_tratados = df.dropna(subset=['title', 'country','date_added','release_year','rating','duration','listed_in'])

# %%
df_sem_colunas = df_dados_tratados.drop(['director','cast','description','country','date_added','rating'], axis=1)

# %%
df_sem_colunas
# Out:
#      show_id     type                                           title  \
# 2         s3    Movie                    Ice Age: A Mammoth Christmas
# 5         s6    Movie                               Becoming Cousteau
# 7         s8  TV Show                          Port Protection Alaska
# 8         s9  TV Show                       Secrets of the Zoo: Tampa
# 9        s10    Movie           A Muppets Christmas: Letters To Santa
# ...      ...      ...                                             ...
# 1445   s1446    Movie                        X-Men Origins: Wolverine
# 1446   s1447    Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                 Eddie the Eagle
# 1448   s1449    Movie                            Bend It Like Beckham
# 1449   s1450    Movie           Captain Sparky vs. The Flying Saucers
#
#       release_year   duration                                      listed_in
# ...

# %%
lista_de_filmes = df_sem_colunas[df_sem_colunas['type'] == 'Movie']

# %%
lista_de_Tv_show = df_sem_colunas[df_sem_colunas['type'] == 'TV Show']

# %%
lista_de_Tv_show
# Out:
#      show_id     type                      title         date_added  \
# 7         s8  TV Show     Port Protection Alaska  November 24, 2021
# 8         s9  TV Show  Secrets of the Zoo: Tampa  November 24, 2021
# 13       s14  TV Show      Dr. Oakley, Yukon Vet  November 17, 2021
# 17       s18  TV Show         Disney Fancy Nancy  November 12, 2021
# 51       s52  TV Show            Disney Amphibia   November 3, 2021
# ...      ...      ...                        ...                ...
# 1406   s1407  TV Show           Wild Yellowstone  November 12, 2019
# 1412   s1413  TV Show   Wizards of Waverly Place  November 12, 2019
# 1414   s1415  TV Show    Wolverine and The X-Men  November 12, 2019
# 1417   s1418  TV Show           X-Men: Evolution  November 12, 2019
# 1434   s1435  TV Show                  Smart Guy    October 1, 2019
#
#       release_year rating    duration  \
# 7             2015  TV-14   2 Seasons
# 8             2019  TV-PG   2 Seasons
# ...

# %%
lista_de_filmes
# Out:
#      show_id   type                                           title  \
# 2         s3  Movie                    Ice Age: A Mammoth Christmas
# 5         s6  Movie                               Becoming Cousteau
# 9        s10  Movie           A Muppets Christmas: Letters To Santa
# 12       s13  Movie                                 The Pixar Story
# 19       s20  Movie                                       Enchanted
# ...      ...    ...                                             ...
# 1445   s1446  Movie                        X-Men Origins: Wolverine
# 1446   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                 Eddie the Eagle
# 1448   s1449  Movie                            Bend It Like Beckham
# 1449   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#               date_added  release_year rating duration  \
# 2      November 26, 2021          2011   TV-G   23 min
# ...
